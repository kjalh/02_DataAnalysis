# %% [markdown]
# pandas는 Python에서 데이터를 쉽고 효율적으로 분석하고 처리하기 위해 사용하는 대표적인 데이터 분석 라이브러리입니다.
# <br>엑셀과 비슷한 형태의 표(Tabular Data)를 다룰 수 있으며, Series와 DataFrame이라는 강력한 자료구조를 제공합니다.
# <br>CSV, Excel, SQL 등의 다양한 데이터 파일을 불러와 정렬, 필터링, 그룹화, 결측치 처리, 통계 분석 등을 간편하게 수행할 수 있으며, 대량의 데이터를 빠르게 가공할 수 있습니다.

# %% [markdown]
# ```
# # 설치
# pip install pandas
# # 또는
# python -m pip install pandas
# ```

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# # **1. Series**
# Series는 Pandas에서 사용하는 가장 기본적인 1차원 데이터 구조로, 값(Value)과 인덱스(Index)가 함께 구성된 자료형입니다.
# <br>NumPy의 1차원 배열과 비슷하지만, 각 데이터에 이름표 역할을 하는 인덱스가 추가되어 데이터를 더 체계적으로 관리할 수 있습니다.
#
# ![시리즈](./images/시리즈.png)

# %%
idx = ['김사과', '반하나', '오렌지', '이메론', '배애리']
data = [67, 75, 90, 62, 98]

# pd.Series(데이터, 인덱스, ...)
pd.Series(data)
# Out:
# 0    67
# 1    75
# 2    90
# 3    62
# 4    98
# dtype: int64

# %%
ser1 = pd.Series(data, idx)
print(ser1)
print(ser1.index)
print(ser1.values)
print(type(ser1.values))
# Out:
# 김사과    67
# 반하나    75
# 오렌지    90
# 이메론    62
# 배애리    98
# dtype: int64
# Index(['김사과', '반하나', '오렌지', '이메론', '배애리'], dtype='str')
# [67 75 90 62 98]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Index 객체란
# Index 객체는 Series와 DataFrame에서 각 데이터의 위치를 식별하고 관리하기 위한 “이름표(Label)” 역할을 하는 자료구조입니다.
# <br>일반 리스트처럼 보이지만 단순한 데이터 저장용이 아니라, 데이터를 빠르게 검색하고 정렬하며 서로 다른 데이터끼리 매칭할 수 있도록 최적화된 Pandas 전용 객체입니다.
#
# ![인덱스 객체](./images/인덱스객체.png)

# %% [markdown]
# # **2. DataFrame**
# 데이터프레임(DataFrame)은 판다스(Pandas) 라이브러리에서 제공하는 중요하고 강력한 데이터 구조로, 2차원의 테이블 형태 데이터를 다루는 데 사용됩니다.
# <br>또한 각 요소는 인덱스(index), 열(column), 값(value)으로 구성되어 있습니다. 데이터프레임은 행과 열로 이루어져 있으며, 각 열은 다양한 데이터 타입을 가질 수 있습니다.
# <br>값은 넘파이의 ndarray 기반으로 저장됩니다.
#
# ![데이터 프레임](./images/데이터프레임.png)

# %%
data = [[67, 93, 91],
        [75, 68, 96],
        [87, 81, 82],
        [62, 70, 75],
        [98, 56, 87]]


idx = ['김사과', '반하나', '오렌지', '이메론', '배애리']
col = ['국어', '영어', '수학']



# pd.DataFrame(데이터, 인덱스, 컬럼, ...)
pd.DataFrame(data)
# Out:
#     0   1   2
# 0  67  93  91
# 1  75  68  96
# 2  87  81  82
# 3  62  70  75
# 4  98  56  87

# %%
pd.DataFrame(data, idx)
# Out:
#       0   1   2
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  87  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %%
pd.DataFrame(data, idx, col)
# Out:
#      국어  영어  수학
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  87  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %%
df = pd.DataFrame(index=idx, columns=col, data=data)  # 순서는 달라도 크게 달라지는 건 없음
df
# Out:
#      국어  영어  수학
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  87  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %%
print(df.index)
print(df.columns)
print(df.values)
# Out:
# Index(['김사과', '반하나', '오렌지', '이메론', '배애리'], dtype='str')
# Index(['국어', '영어', '수학'], dtype='str')
# [[67 93 91]
#  [75 68 96]
#  [87 81 82]
#  [62 70 75]
#  [98 56 87]]

# %%
# 딕셔너리를 사용하여 데이터프레임을 생성하기
dic = {
    '국어':[67, 75, 76, 62, 98],
    '영어':[93, 68, 81, 70, 56],
    '수학':[91, 96, 82, 75, 87]
}
df = pd.DataFrame(data=dic, index=idx)
df
# Out:
#      국어  영어  수학
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  76  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %% [markdown]
# # **3. CSV 파일 읽어오기**
# CSV 파일은 Comma-Separated Values(쉼표로 구분된 값) 파일의 약자로, 데이터를 단순한 텍스트 형식으로 저장하는 데 사용되는 파일 형식입니다.

# %%
df = pd.read_csv('.\광고모델_브랜드평판.csv')
df
# Out:
#      이름          소속사 성별        생년월일        키  혈액형    브랜드평판지수
# 0   변우석     바로엔터테인먼트  남  1991-10-31  190.3cm    B  3,762,141
# 1   임영웅        물고기뮤직  남  1991-06-16  182.2cm    A  3,349,309
# 2   손흥민    로스앤젤레스 FC  남  1992-07-08    183cm   AB  3,067,512
# 3   박지훈     YY엔터테인먼트  남  1999-05-29    173cm   AB  2,831,201
# 4   유재석          안테나  남  1972-08-14    178cm    B  2,015,312
# 5   김연아        올댓스포츠  여  1990-09-05    164cm    O  1,085,281
# 6   이정후  샌프란시스코 자이언츠  남  1998-08-20    185cm    A  1,015,456
# 7   고윤정          MAA  여  1996-04-22    163cm    B    855,724
# 8   김혜윤      아티스트컴퍼니  여  1996-11-10    160cm    B    831,169
# 9   이정재      아티스트컴퍼니  남  1972-12-15    180cm    B    664,985
# 10  마동석    빅펀치엔터테인먼트  남  1971-03-01    178cm    O    651,035
# 11   공유      매니지먼트 숲  남  1979-07-10    184cm    A    561,519
# 12  이준호    JYP엔터테인먼트  남  1990-01-25    178cm    A    543,485
# 13  이찬원     티엔엔터테인먼트  남  1996-11-01    176cm    B    486,700
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   이름       20 non-null     str
#  1   소속사      20 non-null     str
#  2   성별       20 non-null     str
#  3   생년월일     20 non-null     str
#  4   키        20 non-null     str
#  5   혈액형      18 non-null     str
#  6   브랜드평판지수  20 non-null     str
# dtypes: str(7)
# memory usage: 1.2 KB

# %%
df.columns
# Out:
# Index(['이름', '소속사', '성별', '생년월일', '키', '혈액형', '브랜드평판지수'], dtype='str')

# %%
new_columns = ['name', 'company', 'gender', 'birthday', 'height', 'blood', 'brand']
df.columns = new_columns
df
# Out:
#    name      company gender    birthday   height blood      brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31  190.3cm     B  3,762,141
# 1   임영웅        물고기뮤직      남  1991-06-16  182.2cm     A  3,349,309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08    183cm    AB  3,067,512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29    173cm    AB  2,831,201
# 4   유재석          안테나      남  1972-08-14    178cm     B  2,015,312
# 5   김연아        올댓스포츠      여  1990-09-05    164cm     O  1,085,281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20    185cm     A  1,015,456
# 7   고윤정          MAA      여  1996-04-22    163cm     B    855,724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10    160cm     B    831,169
# 9   이정재      아티스트컴퍼니      남  1972-12-15    180cm     B    664,985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01    178cm     O    651,035
# 11   공유      매니지먼트 숲      남  1979-07-10    184cm     A    561,519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25    178cm     A    543,485
# ...

# %%
# describe(): 통계 정보를 교환 
df.describe(include = str)

#df.describe() 여기는 위에랑 값이 같음
# Out:
#        name  company gender    birthday height blood      brand
# count    20       20     20          20     20    18         20
# unique   20       19      2          20     15     4         20
# top     변우석  아티스트컴퍼니      남  1991-10-31  178cm     B  3,762,141
# freq      1        2     15           1      3     7          1

# %% [markdown]
# ![discribe](./images/discribe.png)

# %%
# 원하는 개수의 데이터 보기
df.head()
# Out:
#   name    company gender    birthday   height blood      brand
# 0  변우석   바로엔터테인먼트      남  1991-10-31  190.3cm     B  3,762,141
# 1  임영웅      물고기뮤직      남  1991-06-16  182.2cm     A  3,349,309
# 2  손흥민  로스앤젤레스 FC      남  1992-07-08    183cm    AB  3,067,512
# 3  박지훈   YY엔터테인먼트      남  1999-05-29    173cm    AB  2,831,201
# 4  유재석        안테나      남  1972-08-14    178cm     B  2,015,312

# %%
df.head(3)
# Out:
#   name    company gender    birthday   height blood      brand
# 0  변우석   바로엔터테인먼트      남  1991-10-31  190.3cm     B  3,762,141
# 1  임영웅      물고기뮤직      남  1991-06-16  182.2cm     A  3,349,309
# 2  손흥민  로스앤젤레스 FC      남  1992-07-08    183cm    AB  3,067,512

# %%
df.tail()
# Out:
#    name    company gender    birthday height blood    brand
# 15  박보검     더블랙레이블      남  1993-06-16  182cm     O  451,540
# 16  엄태구        팀호프      남  1983-11-09  181cm     O  380,064
# 17  구교환      나무엑터스      남  1982-12-14  182cm     A  371,673
# 18  지예은  S&A엔터테인먼트      여  1994-07-26  171cm   NaN  370,543
# 19  전지현     이음해시태그      여  1981-10-30  173cm     B  358,271

# %%
df.tail(2)
# Out:
#    name    company gender    birthday height blood    brand
# 18  지예은  S&A엔터테인먼트      여  1994-07-26  171cm   NaN  370,543
# 19  전지현     이음해시태그      여  1981-10-30  173cm     B  358,271

# %% [markdown]
# # **4. 정렬하기**

# %%
df.sort_index() # index로 오름차순 정렬: 기본값
# Out:
#    name      company gender    birthday   height blood      brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31  190.3cm     B  3,762,141
# 1   임영웅        물고기뮤직      남  1991-06-16  182.2cm     A  3,349,309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08    183cm    AB  3,067,512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29    173cm    AB  2,831,201
# 4   유재석          안테나      남  1972-08-14    178cm     B  2,015,312
# 5   김연아        올댓스포츠      여  1990-09-05    164cm     O  1,085,281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20    185cm     A  1,015,456
# 7   고윤정          MAA      여  1996-04-22    163cm     B    855,724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10    160cm     B    831,169
# 9   이정재      아티스트컴퍼니      남  1972-12-15    180cm     B    664,985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01    178cm     O    651,035
# 11   공유      매니지먼트 숲      남  1979-07-10    184cm     A    561,519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25    178cm     A    543,485
# ...

# %%
df.sort_index(ascending=False) # index로 내림차순 정렬
# Out:
#    name      company gender    birthday   height blood      brand
# 19  전지현       이음해시태그      여  1981-10-30    173cm     B    358,271
# 18  지예은    S&A엔터테인먼트      여  1994-07-26    171cm   NaN    370,543
# 17  구교환        나무엑터스      남  1982-12-14    182cm     A    371,673
# 16  엄태구          팀호프      남  1983-11-09    181cm     O    380,064
# 15  박보검       더블랙레이블      남  1993-06-16    182cm     O    451,540
# 14  김도영     KIA 타이거즈      남  2003-10-02    183cm   NaN    481,761
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01    176cm     B    486,700
# 12  이준호    JYP엔터테인먼트      남  1990-01-25    178cm     A    543,485
# 11   공유      매니지먼트 숲      남  1979-07-10    184cm     A    561,519
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01    178cm     O    651,035
# 9   이정재      아티스트컴퍼니      남  1972-12-15    180cm     B    664,985
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10    160cm     B    831,169
# 7   고윤정          MAA      여  1996-04-22    163cm     B    855,724
# ...

# %%
df.sort_values(by='height') # 키로 오름차순 정렬
# Out:
#    name      company gender    birthday   height blood      brand
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10    160cm     B    831,169
# 7   고윤정          MAA      여  1996-04-22    163cm     B    855,724
# 5   김연아        올댓스포츠      여  1990-09-05    164cm     O  1,085,281
# 18  지예은    S&A엔터테인먼트      여  1994-07-26    171cm   NaN    370,543
# 19  전지현       이음해시태그      여  1981-10-30    173cm     B    358,271
# 3   박지훈     YY엔터테인먼트      남  1999-05-29    173cm    AB  2,831,201
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01    176cm     B    486,700
# 12  이준호    JYP엔터테인먼트      남  1990-01-25    178cm     A    543,485
# 4   유재석          안테나      남  1972-08-14    178cm     B  2,015,312
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01    178cm     O    651,035
# 9   이정재      아티스트컴퍼니      남  1972-12-15    180cm     B    664,985
# 16  엄태구          팀호프      남  1983-11-09    181cm     O    380,064
# 1   임영웅        물고기뮤직      남  1991-06-16  182.2cm     A  3,349,309
# ...

# %%
df.sort_values(by='height', ascending=False) # 키로 내림차순 정렬

# 👉  문자열 비교는 사전(Dictionary) 순서처럼 비교하기 때문에 "182cm" > "182.2cm" 처럼 이상한 결과가 나올 수 있습니다.
# 여기서는 .보다 c가 아스키 값이 더 크기 때문에 182.2cm이 작게 나옴
# Out:
#    name      company gender    birthday   height blood      brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31  190.3cm     B  3,762,141
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20    185cm     A  1,015,456
# 11   공유      매니지먼트 숲      남  1979-07-10    184cm     A    561,519
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08    183cm    AB  3,067,512
# 14  김도영     KIA 타이거즈      남  2003-10-02    183cm   NaN    481,761
# 17  구교환        나무엑터스      남  1982-12-14    182cm     A    371,673
# 15  박보검       더블랙레이블      남  1993-06-16    182cm     O    451,540
# 1   임영웅        물고기뮤직      남  1991-06-16  182.2cm     A  3,349,309
# 16  엄태구          팀호프      남  1983-11-09    181cm     O    380,064
# 9   이정재      아티스트컴퍼니      남  1972-12-15    180cm     B    664,985
# 12  이준호    JYP엔터테인먼트      남  1990-01-25    178cm     A    543,485
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01    178cm     O    651,035
# 4   유재석          안테나      남  1972-08-14    178cm     B  2,015,312
# ...

# %%
df['height'] = df['height'].str.replace('cm', '').astype(float)
df
# 👉   cm 문자열을 제거한 뒤 숫자(float)로 변환
# Out:
#    name      company gender    birthday  height blood      brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3,762,141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3,349,309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3,067,512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2,831,201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2,015,312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1,085,281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1,015,456
# 7   고윤정          MAA      여  1996-04-22   163.0     B    855,724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10   160.0     B    831,169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B    664,985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O    651,035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A    561,519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A    543,485
# ...

# %%
# 진짜로 바뀐지 확인
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     str
#  1   company   20 non-null     str
#  2   gender    20 non-null     str
#  3   birthday  20 non-null     str
#  4   height    20 non-null     float64
#  5   blood     18 non-null     str
#  6   brand     20 non-null     str
# dtypes: float64(1), str(6)
# memory usage: 1.2 KB

# %%
df['brand'] = df['brand'].str.replace(',', '').astype(int)
df
# 👉    brand 컬럼도 현재 숫자가 아니라 문자열(String) 상태. 쉼표(,)를 제거한 뒤 숫자로 변환
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10   160.0     B   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     str
#  1   company   20 non-null     str
#  2   gender    20 non-null     str
#  3   birthday  20 non-null     str
#  4   height    20 non-null     float64
#  5   blood     18 non-null     str
#  6   brand     20 non-null     int64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 1.2 KB

# %%
df.describe()
# Out:
#            height         brand
# count   20.000000  2.000000e+01
# mean   177.325000  1.206734e+06
# std      7.906751  1.125405e+06
# min    160.000000  3.582710e+05
# 25%    173.000000  4.742058e+05
# 50%    179.000000  6.580100e+05
# 75%    182.400000  1.317789e+06
# max    190.300000  3.762141e+06

# %% [markdown]
# ![discribe](./images/discribe2.png)

# %%
#df.sort_values(by='height', ascending = False)



# 1차 정렬: 키(내림차순), 2차 정렬: 브랜드(내림차순)
df.sort_values(by = ['height', 'brand'], ascending = False, na_position = 'first')
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 14  김도영     KIA 타이거즈      남  2003-10-02   183.0   NaN   481761
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 15  박보검       더블랙레이블      남  1993-06-16   182.0     O   451540
# 17  구교환        나무엑터스      남  1982-12-14   182.0     A   371673
# 16  엄태구          팀호프      남  1983-11-09   181.0     O   380064
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# ...

# %% [markdown]
# # **5. 인덱싱**

# %%
df.head()
# Out:
#   name    company gender    birthday  height blood    brand
# 0  변우석   바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1  임영웅      물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2  손흥민  로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3  박지훈   YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4  유재석        안테나      남  1972-08-14   178.0     B  2015312

# %%
df['blood']
# 또는
df.blood
# 👉 df['blood']는 컬럼명이 어떤 형태든 비교적 안전하게 사용할 수 있습니다. 예를 들어 컬럼명이 한글이거나, 공백이 있거나, 특수문자가 있으면 df.blood 방식은 사용할 수 없습니다.
# Out:
# 0       B
# 1       A
# 2      AB
# 3      AB
# 4       B
# 5       O
# 6       A
# 7       B
# 8       B
# 9       B
# 10      O
# 11      A
# 12      A
# 13      B
# 14    NaN
# 15      O
# 16      O
# 17      A
# 18    NaN
# 19      B
# Name: blood, dtype: str

# %%
type(df['blood'])
# Out:
# pandas.Series

# %%
df.head(3)
# 또는
df[:3]
# Out:
#   name    company gender    birthday  height blood    brand
# 0  변우석   바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1  임영웅      물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2  손흥민  로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512

# %%
# loc 인덱싱
df.loc[:, 'name'] # df['name'] # 왼쪽은 행 오른쪽은 열
# Out:
# 0     변우석
# 1     임영웅
# 2     손흥민
# 3     박지훈
# 4     유재석
# 5     김연아
# 6     이정후
# 7     고윤정
# 8     김혜윤
# 9     이정재
# 10    마동석
# 11     공유
# 12    이준호
# 13    이찬원
# 14    김도영
# 15    박보검
# 16    엄태구
# 17    구교환
# 18    지예은
# 19    전지현
# Name: name, dtype: str

# %% [markdown]
# > 👉 loc는 DataFrame이나 Series에서 인덱스 이름(Label)과 컬럼명을 기준으로 데이터를 선택하는 인덱서(Indexer)입니다.
# <br> 즉, 숫자 위치가 아니라 실제 행 이름과 열 이름을 사용하여 데이터를 가져옵니다. loc는 사람이 읽기 쉽고 데이터 의미를 기준으로 접근하기 때문에 데이터 분석과 전처리 작업에서 가장 많이 사용하는 방식 중 하나입니다.

# %%
df.loc[2:5, 'name']  # 2부터 5까지 (인덱스를 사용하는게 아니라 인덱스에 들어있는 숫자를 사용. 즉, 인덱스 안에 있는 값을 사용)
# Out:
# 2    손흥민
# 3    박지훈
# 4    유재석
# 5    김연아
# Name: name, dtype: str

# %%
df.loc[2:5, ['name', 'gender', 'height']]
# Out:
#   name gender  height
# 2  손흥민      남   183.0
# 3  박지훈      남   173.0
# 4  유재석      남   178.0
# 5  김연아      여   164.0

# %%
df.loc[[2,5], ['name', 'gender', 'height']]
# Out:
#   name gender  height
# 2  손흥민      남   183.0
# 5  김연아      여   164.0

# %%
df.loc[2:5, 'name':'gender']
# Out:
#   name    company gender
# 2  손흥민  로스앤젤레스 FC      남
# 3  박지훈   YY엔터테인먼트      남
# 4  유재석        안테나      남
# 5  김연아      올댓스포츠      여

# %%
# iloc 인덱싱: index로 인덱싱
df.iloc[:, 0]
# Out:
# 0     변우석
# 1     임영웅
# 2     손흥민
# 3     박지훈
# 4     유재석
# 5     김연아
# 6     이정후
# 7     고윤정
# 8     김혜윤
# 9     이정재
# 10    마동석
# 11     공유
# 12    이준호
# 13    이찬원
# 14    김도영
# 15    박보검
# 16    엄태구
# 17    구교환
# 18    지예은
# 19    전지현
# Name: name, dtype: str

# %% [markdown]
# > 👉 iloc는 DataFrame이나 Series에서 숫자 위치(Index Position)를 기준으로 데이터를 선택하는 인덱서(Indexer)입니다.
# <br> 즉, 실제 인덱스 이름이 아니라 행과 열의 순서 번호를 사용하여 데이터를 가져옵니다. iloc는 데이터의 실제 이름과 상관없이 순서 기준으로 접근하기 때문에 반복 처리나 특정 위치 데이터를 다룰 때 많이 사용됩니다.

# %%
df.iloc[:, 0:3] # 3을 포함하지 않음 # iloc는 인덱스 사용 그래서 0 1 2 즉, 0부터 3개 뽑아라
# Out:
#    name      company gender
# 0   변우석     바로엔터테인먼트      남
# 1   임영웅        물고기뮤직      남
# 2   손흥민    로스앤젤레스 FC      남
# 3   박지훈     YY엔터테인먼트      남
# 4   유재석          안테나      남
# 5   김연아        올댓스포츠      여
# 6   이정후  샌프란시스코 자이언츠      남
# 7   고윤정          MAA      여
# 8   김혜윤      아티스트컴퍼니      여
# 9   이정재      아티스트컴퍼니      남
# 10  마동석    빅펀치엔터테인먼트      남
# 11   공유      매니지먼트 숲      남
# 12  이준호    JYP엔터테인먼트      남
# 13  이찬원     티엔엔터테인먼트      남
# 14  김도영     KIA 타이거즈      남
# 15  박보검       더블랙레이블      남
# 16  엄태구          팀호프      남
# 17  구교환        나무엑터스      남
# 18  지예은    S&A엔터테인먼트      여
# 19  전지현       이음해시태그      여

# %%
df.iloc[:, [0, 3]]
# Out:
#    name    birthday
# 0   변우석  1991-10-31
# 1   임영웅  1991-06-16
# 2   손흥민  1992-07-08
# 3   박지훈  1999-05-29
# 4   유재석  1972-08-14
# 5   김연아  1990-09-05
# 6   이정후  1998-08-20
# 7   고윤정  1996-04-22
# 8   김혜윤  1996-11-10
# 9   이정재  1972-12-15
# 10  마동석  1971-03-01
# 11   공유  1979-07-10
# 12  이준호  1990-01-25
# 13  이찬원  1996-11-01
# 14  김도영  2003-10-02
# 15  박보검  1993-06-16
# 16  엄태구  1983-11-09
# 17  구교환  1982-12-14
# 18  지예은  1994-07-26
# 19  전지현  1981-10-30

# %%
df.iloc[1:5, 0:2]
# Out:
#   name    company
# 1  임영웅      물고기뮤직
# 2  손흥민  로스앤젤레스 FC
# 3  박지훈   YY엔터테인먼트
# 4  유재석        안테나

# %%
df['height'] >= 180 # height 있는 모든 값들과 비교
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19    False
# Name: height, dtype: bool

# %%
df[df['height'] >= 180] # 180이 넘는 모든 값  SELECT * FROM Table WHERE height>= 180
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 14  김도영     KIA 타이거즈      남  2003-10-02   183.0   NaN   481761
# 15  박보검       더블랙레이블      남  1993-06-16   182.0     O   451540
# 16  엄태구          팀호프      남  1983-11-09   181.0     O   380064
# 17  구교환        나무엑터스      남  1982-12-14   182.0     A   371673

# %%
df[df['height'] >= 180] # SELECT name FROM Table WHERE height >= 180
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 14  김도영     KIA 타이거즈      남  2003-10-02   183.0   NaN   481761
# 15  박보검       더블랙레이블      남  1993-06-16   182.0     O   451540
# 16  엄태구          팀호프      남  1983-11-09   181.0     O   380064
# 17  구교환        나무엑터스      남  1982-12-14   182.0     A   371673

# %%
df[df['height'] >= 180][['name', 'gender', 'height']] # SELECT name, gender, height FROM Table  WHERE height >= 180
# Out:
#    name gender  height
# 0   변우석      남   190.3
# 1   임영웅      남   182.2
# 2   손흥민      남   183.0
# 6   이정후      남   185.0
# 9   이정재      남   180.0
# 11   공유      남   184.0
# 14  김도영      남   183.0
# 15  박보검      남   182.0
# 16  엄태구      남   181.0
# 17  구교환      남   182.0

# %%
df.loc[df['height'] >= 180, ['name', 'gender', 'height']] # SELECT name, gender, height FROM Table  WHERE height >= 180
# Out:
#    name gender  height
# 0   변우석      남   190.3
# 1   임영웅      남   182.2
# 2   손흥민      남   183.0
# 6   이정후      남   185.0
# 9   이정재      남   180.0
# 11   공유      남   184.0
# 14  김도영      남   183.0
# 15  박보검      남   182.0
# 16  엄태구      남   181.0
# 17  구교환      남   182.0

# %%
# df.loc[df['height'] >= 180, ['name', 'gender', 'height']]와 같음
df.loc[df['height'] >= 180, ['name', 'gender', 'height']]   # SELECT name, gender, height FROM Table  WHERE height >= 180
# Out:
#    name gender  height
# 0   변우석      남   190.3
# 1   임영웅      남   182.2
# 2   손흥민      남   183.0
# 6   이정후      남   185.0
# 9   이정재      남   180.0
# 11   공유      남   184.0
# 14  김도영      남   183.0
# 15  박보검      남   182.0
# 16  엄태구      남   181.0
# 17  구교환      남   182.0

# %%
blood = ['A', 'B']
df['blood'].isin(blood)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# Name: blood, dtype: bool

# %%
df[df['blood'].isin(blood)] # df.loc[df['blood'].isin(blood),:]  # SELECT * FROM Table WHERE blood IN ('A', 'B')
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10   160.0     B   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# 17  구교환        나무엑터스      남  1982-12-14   182.0     A   371673
# 19  전지현       이음해시태그      여  1981-10-30   173.0     B   358271

# %% [markdown]
# # **6. 결측값**
# 결측값(Missing Value)은 데이터가 존재하지 않거나 비어있는 값을 의미하며, 보통 NaN(Not a Number) 형태로 표현됩니다.
# <br>예를 들어 키, 몸무게, 나이 같은 정보가 입력되지 않았거나 수집 과정에서 누락된 경우 결측값이 발생합니다.
# <br>데이터 분석과 머신러닝에서는 결측값이 매우 중요하며, 그대로 두면 평균 계산, 통계 분석, 모델 학습 과정에서 오류나 성능 저하가 발생할 수 있습니다.
# <br>결측값 처리는 데이터 품질을 높이고 정확한 분석 결과를 얻기 위한 매우 중요한 데이터 전처리 과정입니다.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     str
#  1   company   20 non-null     str
#  2   gender    20 non-null     str
#  3   birthday  20 non-null     str
#  4   height    20 non-null     float64
#  5   blood     18 non-null     str
#  6   brand     20 non-null     int64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 1.2 KB

# %%
df.isna()  # Nan 값이 들어있는 곳을  True로 해서 전부 보여줌
# Out:
#      name  company  gender  birthday  height  blood  brand
# 0   False    False   False     False   False  False  False
# 1   False    False   False     False   False  False  False
# 2   False    False   False     False   False  False  False
# 3   False    False   False     False   False  False  False
# 4   False    False   False     False   False  False  False
# 5   False    False   False     False   False  False  False
# 6   False    False   False     False   False  False  False
# 7   False    False   False     False   False  False  False
# 8   False    False   False     False   False  False  False
# 9   False    False   False     False   False  False  False
# 10  False    False   False     False   False  False  False
# 11  False    False   False     False   False  False  False
# 12  False    False   False     False   False  False  False
# 13  False    False   False     False   False  False  False
# 14  False    False   False     False   False   True  False
# ...

# %%
df.isnull() # 난 이게 편할듯
# Out:
#      name  company  gender  birthday  height  blood  brand
# 0   False    False   False     False   False  False  False
# 1   False    False   False     False   False  False  False
# 2   False    False   False     False   False  False  False
# 3   False    False   False     False   False  False  False
# 4   False    False   False     False   False  False  False
# 5   False    False   False     False   False  False  False
# 6   False    False   False     False   False  False  False
# 7   False    False   False     False   False  False  False
# 8   False    False   False     False   False  False  False
# 9   False    False   False     False   False  False  False
# 10  False    False   False     False   False  False  False
# 11  False    False   False     False   False  False  False
# 12  False    False   False     False   False  False  False
# 13  False    False   False     False   False  False  False
# 14  False    False   False     False   False   True  False
# ...

# %%
df.notna() # 위에 반대
# Out:
#     name  company  gender  birthday  height  blood  brand
# 0   True     True    True      True    True   True   True
# 1   True     True    True      True    True   True   True
# 2   True     True    True      True    True   True   True
# 3   True     True    True      True    True   True   True
# 4   True     True    True      True    True   True   True
# 5   True     True    True      True    True   True   True
# 6   True     True    True      True    True   True   True
# 7   True     True    True      True    True   True   True
# 8   True     True    True      True    True   True   True
# 9   True     True    True      True    True   True   True
# 10  True     True    True      True    True   True   True
# 11  True     True    True      True    True   True   True
# 12  True     True    True      True    True   True   True
# 13  True     True    True      True    True   True   True
# 14  True     True    True      True    True  False   True
# ...

# %%
df.notnull() # 뭐가 편할지 모름 그냥 외우는 거 쓰셈
# Out:
#     name  company  gender  birthday  height  blood  brand
# 0   True     True    True      True    True   True   True
# 1   True     True    True      True    True   True   True
# 2   True     True    True      True    True   True   True
# 3   True     True    True      True    True   True   True
# 4   True     True    True      True    True   True   True
# 5   True     True    True      True    True   True   True
# 6   True     True    True      True    True   True   True
# 7   True     True    True      True    True   True   True
# 8   True     True    True      True    True   True   True
# 9   True     True    True      True    True   True   True
# 10  True     True    True      True    True   True   True
# 11  True     True    True      True    True   True   True
# 12  True     True    True      True    True   True   True
# 13  True     True    True      True    True   True   True
# 14  True     True    True      True    True  False   True
# ...

# %%
#df['height'].isna()
df['height'].isnull() # ()빼면 널이 아닌 값만 보여줌
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: height, dtype: bool

# %%
import numpy as np

# %%
# df.loc[8, 'height'] = np.nan
# df.loc[19, 'height'] = np.nan
df.loc[[8, 19], 'height'] = np.nan

# %%
df[df['height'].isna()]
# Out:
#    name  company gender    birthday  height blood   brand
# 8   김혜윤  아티스트컴퍼니      여  1996-11-10     NaN     B  831169
# 19  전지현   이음해시태그      여  1981-10-30     NaN     B  358271

# %%
df[df['height'].isna()]['name']
# Out:
# 8     김혜윤
# 19    전지현
# Name: name, dtype: str

# %%
df[df['height'].notnull()]
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# 14  김도영     KIA 타이거즈      남  2003-10-02   183.0   NaN   481761
# ...

# %%
df[~df['height'].isnull()]
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# 14  김도영     KIA 타이거즈      남  2003-10-02   183.0   NaN   481761
# ...

# %%
df.loc[df['height'].notnull(), ['name', 'company', 'gender']]
# Out:
#    name      company gender
# 0   변우석     바로엔터테인먼트      남
# 1   임영웅        물고기뮤직      남
# 2   손흥민    로스앤젤레스 FC      남
# 3   박지훈     YY엔터테인먼트      남
# 4   유재석          안테나      남
# 5   김연아        올댓스포츠      여
# 6   이정후  샌프란시스코 자이언츠      남
# 7   고윤정          MAA      여
# 9   이정재      아티스트컴퍼니      남
# 10  마동석    빅펀치엔터테인먼트      남
# 11   공유      매니지먼트 숲      남
# 12  이준호    JYP엔터테인먼트      남
# 13  이찬원     티엔엔터테인먼트      남
# 14  김도영     KIA 타이거즈      남
# 15  박보검       더블랙레이블      남
# 16  엄태구          팀호프      남
# 17  구교환        나무엑터스      남
# 18  지예은    S&A엔터테인먼트      여

# %%
df_copy = df.copy()
df_copy
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10     NaN     B   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# ...

# %%
df_copy['height']
# Out:
# 0     190.3
# 1     182.2
# 2     183.0
# 3     173.0
# 4     178.0
# 5     164.0
# 6     185.0
# 7     163.0
# 8       NaN
# 9     180.0
# 10    178.0
# 11    184.0
# 12    178.0
# 13    176.0
# 14    183.0
# 15    182.0
# 16    181.0
# 17    182.0
# 18    171.0
# 19      NaN
# Name: height, dtype: float64

# %%
# fillna(): 결측값을 채워주는 함수
df_copy['height'].fillna(0)
# Out:
# 0     190.3
# 1     182.2
# 2     183.0
# 3     173.0
# 4     178.0
# 5     164.0
# 6     185.0
# 7     163.0
# 8       0.0
# 9     180.0
# 10    178.0
# 11    184.0
# 12    178.0
# 13    176.0
# 14    183.0
# 15    182.0
# 16    181.0
# 17    182.0
# 18    171.0
# 19      0.0
# Name: height, dtype: float64

# %%
df_copy['height']
# Out:
# 0     190.3
# 1     182.2
# 2     183.0
# 3     173.0
# 4     178.0
# 5     164.0
# 6     185.0
# 7     163.0
# 8       NaN
# 9     180.0
# 10    178.0
# 11    184.0
# 12    178.0
# 13    176.0
# 14    183.0
# 15    182.0
# 16    181.0
# 17    182.0
# 18    171.0
# 19      NaN
# Name: height, dtype: float64

# %%
height = df_copy['height'].mean() # mean() 평균값 내달라 na값(null) 빼고 평균값 냄
height
# Out:
# np.float64(178.52777777777777)

# %%
df_copy['height'] = df_copy['height'].fillna(height)
df_copy['height']
# Out:
# 0     190.300000
# 1     182.200000
# 2     183.000000
# 3     173.000000
# 4     178.000000
# 5     164.000000
# 6     185.000000
# 7     163.000000
# 8     178.527778
# 9     180.000000
# 10    178.000000
# 11    184.000000
# 12    178.000000
# 13    176.000000
# 14    183.000000
# 15    182.000000
# 16    181.000000
# 17    182.000000
# 18    171.000000
# 19    178.527778
# Name: height, dtype: float64

# %%
df_copy = df.copy()  # 데이터 원래대로 돌리기
df_copy['height']
# Out:
# 0     190.3
# 1     182.2
# 2     183.0
# 3     173.0
# 4     178.0
# 5     164.0
# 6     185.0
# 7     163.0
# 8       NaN
# 9     180.0
# 10    178.0
# 11    184.0
# 12    178.0
# 13    176.0
# 14    183.0
# 15    182.0
# 16    181.0
# 17    182.0
# 18    171.0
# 19      NaN
# Name: height, dtype: float64

# %% [markdown]
# ### ※ 평균과 중앙값
# 평균(Mean)은 데이터의 모든 값을 더한 뒤 데이터 개수로 나눈 값으로, 전체 데이터의 중심적인 경향을 나타내는 대표적인 통계값입니다.
# <br>예를 들어 [10, 20, 30]의 평균은 (10+20+30)/3 = 20입니다. 반면 중앙값(Median)은 데이터를 크기순으로 정렬했을 때 가장 가운데 위치한 값을 의미하며,
# <br>이상치(Outlier)의 영향을 적게 받는 특징이 있습니다. 예를 들어 [10, 20, 30]의 중앙값은 20입니다. 만약 데이터 개수가 짝수라 가운데 값이 두 개라면, 두 가운데 값의 평균을 중앙값으로 사용합니다.
# <br>예를 들어 [10, 20, 30, 40]에서는 가운데 값인 20과 30의 평균인 25가 중앙값이 됩니다. 따라서 평균은 전체 데이터를 모두 반영하는 대표값이고, 중앙값은 데이터의 정중앙 위치를 나타내는 대표값이라고 할 수 있습니다.

# %%
height = df_copy['height'].median() # 50%값, 중위  값들의 중간값이 아니라 배열에 있는 중간값(가운데값이 두 개면 평균을 내 중간값 사용)
height
# Out:
# np.float64(180.5)

# %%
df_copy['height'] = df_copy['height'].fillna(height)
df_copy['height']
# Out:
# 0     190.3
# 1     182.2
# 2     183.0
# 3     173.0
# 4     178.0
# 5     164.0
# 6     185.0
# 7     163.0
# 8     180.5
# 9     180.0
# 10    178.0
# 11    184.0
# 12    178.0
# 13    176.0
# 14    183.0
# 15    182.0
# 16    181.0
# 17    182.0
# 18    171.0
# 19    180.5
# Name: height, dtype: float64

# %%
df_copy = df.copy()
df_copy
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10     NaN     B   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# ...

# %%
# dropna(): 결측값이 있는 행 또는 열을 제거. 결측값이 한개라도 있는 경우 삭제
# axis=0 (행 삭제)
df_copy.dropna()
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# 15  박보검       더블랙레이블      남  1993-06-16   182.0     O   451540
# ...

# %%
df_copy.dropna(axis=1) # 결측값이 있는 열을 제거
# Out:
#    name      company gender    birthday    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29  2831201
# 4   유재석          안테나      남  1972-08-14  2015312
# 5   김연아        올댓스포츠      여  1990-09-05  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20  1015456
# 7   고윤정          MAA      여  1996-04-22   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   486700
# 14  김도영     KIA 타이거즈      남  2003-10-02   481761
# 15  박보검       더블랙레이블      남  1993-06-16   451540
# 16  엄태구          팀호프      남  1983-11-09   380064
# 17  구교환        나무엑터스      남  1982-12-14   371673
# ...

# %% [markdown]
# # **7. 행, 열 추가 및 삭제**

# %%
# df_copy = df.copy()
# df_copy

# %%
dic = {
    'name': '김사과',
    'company': '애플',
    'gender': '여자',
    'birthday': '2000-01-01',
    'height': 160.0,
    'blood': 'A',
    'brand': 1234567
}

# %%
df_copy.loc[len(df_copy)] = dic  # 맨 뒷 번호에 데이터 삽입방식
df_copy
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10     NaN     B   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# ...

# %%
df_copy['nation'] = '대한민국'
df_copy.head()
# Out:
#   name    company gender    birthday  height blood    brand nation
# 0  변우석   바로엔터테인먼트      남  1991-10-31   190.3     B  3762141   대한민국
# 1  임영웅      물고기뮤직      남  1991-06-16   182.2     A  3349309   대한민국
# 2  손흥민  로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512   대한민국
# 3  박지훈   YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201   대한민국
# 4  유재석        안테나      남  1972-08-14   178.0     B  2015312   대한민국

# %%
df_copy.tail()
# Out:
#    name    company gender    birthday  height blood    brand nation
# 17  구교환      나무엑터스      남  1982-12-14   182.0     A   371673   대한민국
# 18  지예은  S&A엔터테인먼트      여  1994-07-26   171.0   NaN   370543   대한민국
# 19  전지현     이음해시태그      여  1981-10-30     NaN     B   358271   대한민국
# 20  김사과         애플     여자  2000-01-01   160.0     A  1234567   대한민국
# 21  김사과         애플     여자  2000-01-01   160.0     A  1234567   대한민국

# %%
df_copy.loc[df_copy['name'] == '김사과', 'nation'] = '미국'
df_copy.tail()
# Out:
#    name    company gender    birthday  height blood    brand nation
# 17  구교환      나무엑터스      남  1982-12-14   182.0     A   371673   대한민국
# 18  지예은  S&A엔터테인먼트      여  1994-07-26   171.0   NaN   370543   대한민국
# 19  전지현     이음해시태그      여  1981-10-30     NaN     B   358271   대한민국
# 20  김사과         애플     여자  2000-01-01   160.0     A  1234567     미국
# 21  김사과         애플     여자  2000-01-01   160.0     A  1234567     미국

# %%
# 행 제거하기
df_copy.drop(20, axis=0) # 0: 행, 1: 열
# Out:
#    name      company gender    birthday  height blood    brand nation
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141   대한민국
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309   대한민국
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512   대한민국
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201   대한민국
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312   대한민국
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281   대한민국
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456   대한민국
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724   대한민국
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10     NaN     B   831169   대한민국
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985   대한민국
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035   대한민국
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519   대한민국
# ...

# %%
df_copy.tail()
# Out:
#    name    company gender    birthday  height blood    brand nation
# 17  구교환      나무엑터스      남  1982-12-14   182.0     A   371673   대한민국
# 18  지예은  S&A엔터테인먼트      여  1994-07-26   171.0   NaN   370543   대한민국
# 19  전지현     이음해시태그      여  1981-10-30     NaN     B   358271   대한민국
# 20  김사과         애플     여자  2000-01-01   160.0     A  1234567     미국
# 21  김사과         애플     여자  2000-01-01   160.0     A  1234567     미국

# %%
df_copy.drop([1, 3, 5, 7, 20], axis=0)
# Out:
#    name      company gender    birthday  height blood    brand nation
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141   대한민국
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512   대한민국
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312   대한민국
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456   대한민국
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10     NaN     B   831169   대한민국
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985   대한민국
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035   대한민국
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519   대한민국
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485   대한민국
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700   대한민국
# 14  김도영     KIA 타이거즈      남  2003-10-02   183.0   NaN   481761   대한민국
# 15  박보검       더블랙레이블      남  1993-06-16   182.0     O   451540   대한민국
# ...

# %%
# 열 제거하기
df_copy.drop('nation', axis=1)
# Out:
#    name      company gender    birthday  height blood    brand
# 0   변우석     바로엔터테인먼트      남  1991-10-31   190.3     B  3762141
# 1   임영웅        물고기뮤직      남  1991-06-16   182.2     A  3349309
# 2   손흥민    로스앤젤레스 FC      남  1992-07-08   183.0    AB  3067512
# 3   박지훈     YY엔터테인먼트      남  1999-05-29   173.0    AB  2831201
# 4   유재석          안테나      남  1972-08-14   178.0     B  2015312
# 5   김연아        올댓스포츠      여  1990-09-05   164.0     O  1085281
# 6   이정후  샌프란시스코 자이언츠      남  1998-08-20   185.0     A  1015456
# 7   고윤정          MAA      여  1996-04-22   163.0     B   855724
# 8   김혜윤      아티스트컴퍼니      여  1996-11-10     NaN     B   831169
# 9   이정재      아티스트컴퍼니      남  1972-12-15   180.0     B   664985
# 10  마동석    빅펀치엔터테인먼트      남  1971-03-01   178.0     O   651035
# 11   공유      매니지먼트 숲      남  1979-07-10   184.0     A   561519
# 12  이준호    JYP엔터테인먼트      남  1990-01-25   178.0     A   543485
# 13  이찬원     티엔엔터테인먼트      남  1996-11-01   176.0     B   486700
# ...

# %%
df_copy.drop(['nation', 'company'], axis=1)
# Out:
#    name gender    birthday  height blood    brand
# 0   변우석      남  1991-10-31   190.3     B  3762141
# 1   임영웅      남  1991-06-16   182.2     A  3349309
# 2   손흥민      남  1992-07-08   183.0    AB  3067512
# 3   박지훈      남  1999-05-29   173.0    AB  2831201
# 4   유재석      남  1972-08-14   178.0     B  2015312
# 5   김연아      여  1990-09-05   164.0     O  1085281
# 6   이정후      남  1998-08-20   185.0     A  1015456
# 7   고윤정      여  1996-04-22   163.0     B   855724
# 8   김혜윤      여  1996-11-10     NaN     B   831169
# 9   이정재      남  1972-12-15   180.0     B   664985
# 10  마동석      남  1971-03-01   178.0     O   651035
# 11   공유      남  1979-07-10   184.0     A   561519
# 12  이준호      남  1990-01-25   178.0     A   543485
# 13  이찬원      남  1996-11-01   176.0     B   486700
# 14  김도영      남  2003-10-02   183.0   NaN   481761
# 15  박보검      남  1993-06-16   182.0     O   451540
# 16  엄태구      남  1983-11-09   181.0     O   380064
# 17  구교환      남  1982-12-14   182.0     A   371673
# ...

# %% [markdown]
# # **8. 통계 함수**

# %%
print(df_copy['height'].sum()) # 합계
print(df_copy['height'].count()) # 개수, NaN은 포함하지 않음
print(df_copy['height'].mean()) # 평균
print(df_copy['height'].median()) # 중앙값
print(df_copy['height'].max()) # 최대값
print(df_copy['height'].min()) # 최소값
print(df_copy['height'].var()) # 분산
print(df_copy['height'].std()) # 표준편차
# Out:
# 3533.5
# 20
# 176.675
# 179.0
# 190.3
# 160.0
# 76.88513157894738
# 8.768416708787703

# %% [markdown]
# ※ 분산과 표준편차
# 분산(Variance)은 데이터가 평균으로부터 얼마나 퍼져 있는지를 수치로 나타낸 값으로, 각 데이터와 평균의 차이를 제곱한 뒤 평균을 내어 계산합니다.
# <br>값이 클수록 데이터의 흩어짐이 크다는 의미이며, 값이 작을수록 데이터가 평균 근처에 모여 있다는 뜻입니다.
# <br>하지만 분산은 차이를 제곱해서 계산하기 때문에 단위가 원래 데이터와 달라진다는 단점이 있습니다.
# <br>이를 해결하기 위해 사용하는 것이 표준편차(Standard Deviation)이며, 표준편차는 분산에 제곱근(sqrt)을 취한 값입니다.
# <br>따라서 원래 데이터와 같은 단위를 사용하므로 해석이 더 직관적입니다.
#
# ![분산과 표준편차](./images/분산과표준편차.png)

# %%
# groupby(): 데이터를 그룹으로 묶어 분석할 때 사용
df_copy.groupby('blood')

# %%
# 그룹을 맺으면 통계함수를 사용할 수 있음
df_copy.groupby('blood').count()
# Out:
#        name  company  gender  birthday  height  brand  nation
# blood
# A         7        7       7         7       7      7       7
# AB        2        2       2         2       2      2       2
# B         7        7       7         7       5      7       7
# O         4        4       4         4       4      4       4

# %%
df_copy.groupby('blood').mean(numeric_only=True)
# Out:
#            height         brand
# blood
# A      175.885714  1.187225e+06
# AB     178.000000  2.949356e+06
# B      177.460000  1.282043e+06
# O      176.250000  6.419800e+05

# %%
df_copy.groupby('blood').sum(numeric_only=True)
# Out:
#        height    brand
# blood
# A      1231.2  8310576
# AB      356.0  5898713
# B       887.3  8974302
# O       705.0  2567920

# %%
df_copy.groupby(['blood','gender']).mean(numeric_only=True)
# Out:
#                   height         brand
# blood gender
# A     남       182.240000  1.168288e+06
#       여자      160.000000  1.234567e+06
# AB    남       178.000000  2.949356e+06
# B     남       181.075000  1.732284e+06
#       여       163.000000  6.817213e+05
# O     남       180.333333  4.942130e+05
#       여       164.000000  1.085281e+06

# %%
df_copy.groupby(['blood','gender'])['height'].mean()
# Out:
# blood  gender
# A      남         182.240000
#        여자        160.000000
# AB     남         178.000000
# B      남         181.075000
#        여         163.000000
# O      남         180.333333
#        여         164.000000
# Name: height, dtype: float64

# %%
df_copy['blood']
# Out:
# 0       B
# 1       A
# 2      AB
# 3      AB
# 4       B
# 5       O
# 6       A
# 7       B
# 8       B
# 9       B
# 10      O
# 11      A
# 12      A
# 13      B
# 14    NaN
# 15      O
# 16      O
# 17      A
# 18    NaN
# 19      B
# 20      A
# 21      A
# Name: blood, dtype: str

# %%
# drop_duplicates(): 중복된 데이터를 제거, keep='first' 기본값
# df_copy['blood'].drop_duplicates(keep='last')
df_copy['blood'].drop_duplicates() # 어떤 값이 있는지 알기 좋음
# Out:
# 0       B
# 1       A
# 2      AB
# 5       O
# 14    NaN
# Name: blood, dtype: str

# %%
# value_counts(): 열의 각 값에 대한 데이터의 개수를 반환. 기본은 NaN을 생략
df_copy['blood'].value_counts(dropna=False) # NaN를 포함
#df_copy['blood'].value_counts() # 기본값
# Out:
# blood
# B      7
# A      7
# O      4
# AB     2
# NaN    2
# Name: count, dtype: int64
